# %% [markdown]
# ## Marketing data team analysis
# ### Based on the cost, analyse and give feedback on why some campaigns should be discontinued

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wrn
wrn.filterwarnings("ignore")

# %%
df = pd.read_csv('Marketing Team Data - Sheet1.csv')

# %%
df.head()
# Out:
#   campaign ID                             Campaign Name  \
# 0  Campaign 1          SHU_6 (Educators and Principals)
# 1  Campaign 1          SHU_6 (Educators and Principals)
# 2  Campaign 1          SHU_6 (Educators and Principals)
# 3  Campaign 1          SHU_6 (Educators and Principals)
# 4  Campaign 2  SHU3_ (Students Apart from India and US)
#
#                    Audience    Age  \
# 0  Educators and Principals  25-34
# 1  Educators and Principals  35-44
# 2  Educators and Principals  45-54
# 3  Educators and Principals  55-64
# 4                  Students  18-24
#
#                                            Geography  Reach  Impressions  \
# 0  Group 1 (Australia, Canada, United Kingdom, Gh...  11387        23283
# 1  Group 1 (Australia, Canada, United Kingdom, Gh...   8761        15683
# 2  Group 1 (Australia, Canada, United Kingdom, Gh...   2867         6283
# 3  Group 1 (Australia, Canada, United Kingdom, Gh...    889         1890
# 4  Group 2 (Australia, Canada, United Kingdom, Gh...  29675        39161
#
#    Frequency  Clicks  Unique Clicks  Unique Link Clicks (ULC)  \
# 0   2.044700     487            406                       180
# 1   1.790092     484            376                       154
# 2   2.191489     198            145                        65
# 3   2.125984      49             40                        21
# 4   1.319663    2593           1994                      1095
#
#    Click-Through Rate (CTR in %)  Unique Click-Through Rate (Unique CTR in %)  \
# 0                           2.09                                         3.57
# 1                           3.09                                         4.29
# 2                           3.15                                         5.06
# 3                           2.59                                         4.50
# 4                           6.62                                         6.72
#
#   Amount Spent in INR Cost Per Click (CPC) Cost per Result (CPR)  @dropdown  \
# 0           $1,092.24                $2.24                 $6.07        NaN
# 1             $835.46                $1.73                 $5.43        NaN
# 2             $319.38                $1.61                 $4.91        NaN
# 3              $86.25                $1.76                 $4.11        NaN
# 4           $1,193.94                $0.46                 $1.09        NaN
#
#    @dropdown.1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   campaign ID                                  33 non-null     object
#  1   Campaign Name                                33 non-null     object
#  2   Audience                                     33 non-null     object
#  3   Age                                          33 non-null     object
#  4   Geography                                    33 non-null     object
#  5   Reach                                        33 non-null     int64
#  6   Impressions                                  33 non-null     int64
#  7   Frequency                                    33 non-null     float64
#  8   Clicks                                       33 non-null     int64
#  9   Unique Clicks                                33 non-null     int64
#  10  Unique Link Clicks (ULC)                     33 non-null     int64
#  11  Click-Through Rate (CTR in %)                33 non-null     float64
#  12  Unique Click-Through Rate (Unique CTR in %)  33 non-null     float64
#  13  Amount Spent in INR                          33 non-null     object
#  14  Cost Per Click (CPC)                         33 non-null     object
#  15  Cost per Result (CPR)                        33 non-null     object
#  16  @dropdown                                    0 non-null      float64
#  17  @dropdown.1                                  0 non-null      float64
# dtypes: float64(5), int64(5), object(8)
# memory usage: 4.8+ KB

# %% [markdown]
# ## Checking for missing values

# %%
df.isnull().sum()
# Out:
# campaign ID                                     0
# Campaign Name                                   0
# Audience                                        0
# Age                                             0
# Geography                                       0
# Reach                                           0
# Impressions                                     0
# Frequency                                       0
# Clicks                                          0
# Unique Clicks                                   0
# Unique Link Clicks (ULC)                        0
# Click-Through Rate (CTR in %)                   0
# Unique Click-Through Rate (Unique CTR in %)     0
# Amount Spent in INR                             0
# Cost Per Click (CPC)                            0
# Cost per Result (CPR)                           0
# @dropdown                                      33
# @dropdown.1                                    33
# dtype: int64

# %%
df.dropna(axis=1, how='all',inplace=True)
df.head()
# Out:
#   campaign ID                             Campaign Name  \
# 0  Campaign 1          SHU_6 (Educators and Principals)
# 1  Campaign 1          SHU_6 (Educators and Principals)
# 2  Campaign 1          SHU_6 (Educators and Principals)
# 3  Campaign 1          SHU_6 (Educators and Principals)
# 4  Campaign 2  SHU3_ (Students Apart from India and US)
#
#                    Audience    Age  \
# 0  Educators and Principals  25-34
# 1  Educators and Principals  35-44
# 2  Educators and Principals  45-54
# 3  Educators and Principals  55-64
# 4                  Students  18-24
#
#                                            Geography  Reach  Impressions  \
# 0  Group 1 (Australia, Canada, United Kingdom, Gh...  11387        23283
# 1  Group 1 (Australia, Canada, United Kingdom, Gh...   8761        15683
# 2  Group 1 (Australia, Canada, United Kingdom, Gh...   2867         6283
# 3  Group 1 (Australia, Canada, United Kingdom, Gh...    889         1890
# 4  Group 2 (Australia, Canada, United Kingdom, Gh...  29675        39161
#
#    Frequency  Clicks  Unique Clicks  Unique Link Clicks (ULC)  \
# 0   2.044700     487            406                       180
# 1   1.790092     484            376                       154
# 2   2.191489     198            145                        65
# 3   2.125984      49             40                        21
# 4   1.319663    2593           1994                      1095
#
#    Click-Through Rate (CTR in %)  Unique Click-Through Rate (Unique CTR in %)  \
# 0                           2.09                                         3.57
# 1                           3.09                                         4.29
# 2                           3.15                                         5.06
# 3                           2.59                                         4.50
# 4                           6.62                                         6.72
#
#   Amount Spent in INR Cost Per Click (CPC) Cost per Result (CPR)
# 0           $1,092.24                $2.24                 $6.07
# 1             $835.46                $1.73                 $5.43
# 2             $319.38                $1.61                 $4.91
# 3              $86.25                $1.76                 $4.11
# 4           $1,193.94                $0.46                 $1.09

# %%
df.columns = ["CAMPAIGN ID","CAMPAIGN NAME","AUDIENCE","AGE","GEOGRAPHY","REACH","IMPRESSIONS","FREQUENCY","CLICKS","UNIQUE CLICKS","UNIQUE LINK CLICKS","CLICK THROUGH RATE","UNIQUE CTR","AMOUNT SPENT ","COST PER CLICK","COST PER RESULT"]
df.head()
# Out:
#   CAMPAIGN ID                             CAMPAIGN NAME  \
# 0  Campaign 1          SHU_6 (Educators and Principals)
# 1  Campaign 1          SHU_6 (Educators and Principals)
# 2  Campaign 1          SHU_6 (Educators and Principals)
# 3  Campaign 1          SHU_6 (Educators and Principals)
# 4  Campaign 2  SHU3_ (Students Apart from India and US)
#
#                    AUDIENCE    AGE  \
# 0  Educators and Principals  25-34
# 1  Educators and Principals  35-44
# 2  Educators and Principals  45-54
# 3  Educators and Principals  55-64
# 4                  Students  18-24
#
#                                            GEOGRAPHY  REACH  IMPRESSIONS  \
# 0  Group 1 (Australia, Canada, United Kingdom, Gh...  11387        23283
# 1  Group 1 (Australia, Canada, United Kingdom, Gh...   8761        15683
# 2  Group 1 (Australia, Canada, United Kingdom, Gh...   2867         6283
# 3  Group 1 (Australia, Canada, United Kingdom, Gh...    889         1890
# 4  Group 2 (Australia, Canada, United Kingdom, Gh...  29675        39161
#
#    FREQUENCY  CLICKS  UNIQUE CLICKS  UNIQUE LINK CLICKS  CLICK THROUGH RATE  \
# 0   2.044700     487            406                 180                2.09
# 1   1.790092     484            376                 154                3.09
# 2   2.191489     198            145                  65                3.15
# 3   2.125984      49             40                  21                2.59
# 4   1.319663    2593           1994                1095                6.62
#
#    UNIQUE CTR AMOUNT SPENT  COST PER CLICK COST PER RESULT
# 0        3.57     $1,092.24          $2.24           $6.07
# 1        4.29       $835.46          $1.73           $5.43
# 2        5.06       $319.38          $1.61           $4.91
# 3        4.50        $86.25          $1.76           $4.11
# 4        6.72     $1,193.94          $0.46           $1.09

# %% [markdown]
# ## Converting currency fields into float values

# %%
currency_cols = ['AMOUNT SPENT ', 'COST PER CLICK', 'COST PER RESULT']

for col in currency_cols:
    df[col] = df[col].replace({'\$|,': ''}, regex=True).astype(float)
print(df.to_string())
# Out:
#     CAMPAIGN ID                             CAMPAIGN NAME                  AUDIENCE    AGE                                                                                              GEOGRAPHY  REACH  IMPRESSIONS  FREQUENCY  CLICKS  UNIQUE CLICKS  UNIQUE LINK CLICKS  CLICK THROUGH RATE  UNIQUE CTR  AMOUNT SPENT   COST PER CLICK  COST PER RESULT
# 0    Campaign 1          SHU_6 (Educators and Principals)  Educators and Principals  25-34                   Group 1 (Australia, Canada, United Kingdom, Ghana, Nigeria, Pakistan, United States)  11387        23283   2.044700     487            406                 180                2.09        3.57        1092.24            2.24             6.07
# 1    Campaign 1          SHU_6 (Educators and Principals)  Educators and Principals  35-44                   Group 1 (Australia, Canada, United Kingdom, Ghana, Nigeria, Pakistan, United States)   8761        15683   1.790092     484            376                 154                3.09        4.29         835.46            1.73             5.43
# 2    Campaign 1          SHU_6 (Educators and Principals)  Educators and Principals  45-54                   Group 1 (Australia, Canada, United Kingdom, Ghana, Nigeria, Pakistan, United States)   2867         6283   2.191489     198            145                  65                3.15        5.06         319.38            1.61             4.91
# 3    Campaign 1          SHU_6 (Educators and Principals)  Educators and Principals  55-64                   Group 1 (Australia, Canada, United Kingdom, Ghana, Nigeria, Pakistan, United States)    889         1890   2.125984      49             40                  21                2.59        4.50          86.25            1.76             4.11
# 4    Campaign 2  SHU3_ (Students Apart from India and US)                  Students  18-24  Group 2 (Australia, Canada, United Kingdom, Ghana, Niger, Nigeria, Nepal, Pakistan, Thailand, Taiwan)  29675        39161   1.319663    2593           1994                1095                6.62        6.72        1193.94            0.46             1.09
# 5    Campaign 2  SHU3_ (Students Apart from India and US)                  Students  13-17  Group 2 (Australia, Canada, United Kingdom, Ghana, Niger, Nigeria, Nepal, Pakistan, Thailand, Taiwan)  14753        25705   1.742357     969            698                 435                3.77        4.73         299.51            0.31             0.69
# 6    Campaign 2  SHU3_ (Students Apart from India and US)                  Students  25-34  Group 2 (Australia, Canada, United Kingdom, Ghana, Niger, Nigeria, Nepal, Pakistan, Thailand, Taiwan)   2066         2447   1.184414     181            141                  65                7.40        6.82          85.57            0.47             1.32
# 7    Campaign 3                   SHU_Students(Australia)                  Students  13-17                                                                                              Australia   2271         2616   1.151915      61             55                  28                2.33        2.42         475.85            7.80            16.99
# 8    Campaign 3                   SHU_Students(Australia)                  Students  18-24                                                                                              Australia    704          734   1.042614      49             46                  13                6.68        6.53         283.17            5.78            21.78
# 9    Campaign 3                   SHU_Students(Australia)                  Students  25-34                                                                                              Australia    212          222   1.047170       9              8                   3                4.05        3.77          91.66           10.18            30.55
# 10   Campaign 4                     SHU_Students (Canada)                  Students  13-17                                                                                                 Canada   2330         3146   1.350215     101             84                  63                3.21        3.61         528.08            5.23             8.38
# 11   Campaign 4                     SHU_Students (Canada)                  Students  18-24                                                                                                 Canada    759          878   1.156785      52             44                  34                5.92        5.80         294.82            5.67             8.67
# 12   Campaign 4                     SHU_Students (Canada)                  Students  25-34                                                                                                 Canada    218          243   1.114679      18             18                  15                7.41        8.26         101.06            5.61             6.74
# 13   Campaign 5                       SHU_Students(Ghana)                  Students  18-24                                                                                                  Ghana   5952         6943   1.166499     284            238                  98                4.09        4.00         378.10            1.33             3.86
# 14   Campaign 5                       SHU_Students(Ghana)                  Students  25-34                                                                                                  Ghana   3717         4620   1.242938     184            160                  46                3.98        4.30         282.22            1.53             6.14
# 15   Campaign 5                       SHU_Students(Ghana)                  Students  13-17                                                                                                  Ghana   5355         8920   1.665733     180            154                  93                2.02        2.88         177.46            0.99             1.91
# 16   Campaign 6                      SHU_Students (India)                  Students  18-24                                                                                                  India  30110        35372   1.174759    1308           1162                 934                3.70        3.86         894.00            0.68             0.96
# 17   Campaign 6                      SHU_Students (India)                  Students  25-34                                                                                                  India   1721         1874   1.088902      92             76                  53                4.91        4.42          61.21            0.67             1.15
# 18   Campaign 7                       SHU_Students(Nepal)                  Students  18-24                                                                                                  Nepal  18900        36659   1.939630     849            688                 306                2.32        3.64         634.64            0.75             2.07
# 19   Campaign 7                       SHU_Students(Nepal)                  Students  13-17                                                                                                  Nepal   6145        19474   3.169081     325            246                 129                1.67        4.00         211.76            0.65             1.64
# 20   Campaign 7                       SHU_Students(Nepal)                  Students  25-34                                                                                                  Nepal   4623         9082   1.964525     246            212                  83                2.71        4.59         188.84            0.77             2.28
# 21   Campaign 8                    SHU_Students (Nigeria)                  Students  18-24                                                                                                Nigeria  11027        13820   1.253287    1491           1132                 548               10.79       10.27         542.67            0.36             0.99
# 22   Campaign 8                    SHU_Students (Nigeria)                  Students  13-17                                                                                                Nigeria   8516        12372   1.452795     970            696                 408                7.84        8.17         282.21            0.29             0.69
# 23   Campaign 8                    SHU_Students (Nigeria)                  Students  25-34                                                                                                Nigeria   2386         2782   1.165968     304            230                 117               10.93        9.64         117.90            0.39             1.01
# 24   Campaign 9                         SHU_Students(UAE)                  Students  25-34                                                                                                    UAE   2892         3347   1.157331     135            102                  41                4.03        3.53         455.49            3.37            11.11
# 25   Campaign 9                         SHU_Students(UAE)                  Students  18-24                                                                                                    UAE   2862         3234   1.129979      72             60                  27                2.23        2.10         316.14            4.39            11.71
# 26   Campaign 9                         SHU_Students(UAE)                  Students  13-17                                                                                                    UAE   1579         2079   1.316656      35             32                  20                1.68        2.03         104.63            2.99             5.23
# 27  Campaign 10                          SHU_Students(UK)                  Students  13-17                                                                                                     UK   2557         2941   1.150176      69             60                  33                2.35        2.35         487.52            7.07            14.77
# 28  Campaign 10                          SHU_Students(UK)                  Students  18-24                                                                                                     UK    741          785   1.059379      39             34                  20                4.97        4.59         255.57            6.55            12.78
# 29  Campaign 10                          SHU_Students(UK)                  Students  25-34                                                                                                     UK    338          365   1.079882      13             11                   4                3.56        3.25         113.58            8.74            28.40
# 30  Campaign 11                        SHU_Students (USA)                  Students  13-17                                                                                                    USA   2159         2465   1.141732     126            111                  95                5.11        5.14         691.28            5.49             7.28
# 31  Campaign 11                        SHU_Students (USA)                  Students  18-24                                                                                                    USA    305          332   1.088525      43             37                  28               12.95       12.13         159.14            3.70             5.68
# 32  Campaign 11                        SHU_Students (USA)                  Students  25-34                                                                                                    USA     91          103   1.131868       9              8                   3                8.74        8.79          47.26            5.25            15.75

# %% [markdown]
# ## Checking for correlation

# %%
df.corr(numeric_only=True)
# Out:
#                        REACH  IMPRESSIONS  FREQUENCY    CLICKS  UNIQUE CLICKS  \
# REACH               1.000000     0.954161   0.190143  0.895300       0.918396
# IMPRESSIONS         0.954161     1.000000   0.415266  0.830217       0.846363
# FREQUENCY           0.190143     0.415266   1.000000  0.110370       0.103685
# CLICKS              0.895300     0.830217   0.110370  1.000000       0.997378
# UNIQUE CLICKS       0.918396     0.846363   0.103685  0.997378       1.000000
# UNIQUE LINK CLICKS  0.940743     0.837661   0.056021  0.962116       0.974685
# CLICK THROUGH RATE -0.083845    -0.183359  -0.437479  0.173884       0.155438
# UNIQUE CTR         -0.034556    -0.083864  -0.200013  0.218590       0.197706
# AMOUNT SPENT        0.734962     0.706480   0.104292  0.654750       0.675300
# COST PER CLICK     -0.510547    -0.551133  -0.464787 -0.516185      -0.514501
# COST PER RESULT    -0.448289    -0.476624  -0.401623 -0.450283      -0.450287
#
#                     UNIQUE LINK CLICKS  CLICK THROUGH RATE  UNIQUE CTR  \
# REACH                         0.940743           -0.083845   -0.034556
# IMPRESSIONS                   0.837661           -0.183359   -0.083864
# FREQUENCY                     0.056021           -0.437479   -0.200013
# CLICKS                        0.962116            0.173884    0.218590
# UNIQUE CLICKS                 0.974685            0.155438    0.197706
# UNIQUE LINK CLICKS            1.000000            0.133640    0.162622
# CLICK THROUGH RATE            0.133640            1.000000    0.958489
# UNIQUE CTR                    0.162622            0.958489    1.000000
# AMOUNT SPENT                  0.655917           -0.180669   -0.160659
# COST PER CLICK               -0.478640           -0.083977   -0.205092
# COST PER RESULT              -0.435268           -0.110711   -0.231066
#
#                     AMOUNT SPENT   COST PER CLICK  COST PER RESULT
# REACH                    0.734962       -0.510547        -0.448289
# IMPRESSIONS              0.706480       -0.551133        -0.476624
# FREQUENCY                0.104292       -0.464787        -0.401623
# CLICKS                   0.654750       -0.516185        -0.450283
# UNIQUE CLICKS            0.675300       -0.514501        -0.450287
# UNIQUE LINK CLICKS       0.655917       -0.478640        -0.435268
# CLICK THROUGH RATE      -0.180669       -0.083977        -0.110711
# UNIQUE CTR              -0.160659       -0.205092        -0.231066
# AMOUNT SPENT             1.000000       -0.185950        -0.212319
# COST PER CLICK          -0.185950        1.000000         0.909952
# COST PER RESULT         -0.212319        0.909952         1.000000

# %%
# ...existing code...

campaign_summary = df.groupby('CAMPAIGN NAME').agg({
    'AMOUNT SPENT ': 'sum',
    'CLICKS': 'sum',
    'IMPRESSIONS': 'sum',
    'REACH': 'sum',
    'CLICK THROUGH RATE': 'mean',
    'COST PER CLICK': 'mean',
    'COST PER RESULT': 'mean',
}).sort_values(by='AMOUNT SPENT ', ascending=False).reset_index()

# Display summary table
campaign_summary

# ...existing code...
# Out:
#                                CAMPAIGN NAME  AMOUNT SPENT   CLICKS  \
# 0           SHU_6 (Educators and Principals)        2333.33    1218
# 1   SHU3_ (Students Apart from India and US)        1579.02    3743
# 2                        SHU_Students(Nepal)        1035.24    1420
# 3                       SHU_Students (India)         955.21    1400
# 4                     SHU_Students (Nigeria)         942.78    2765
# 5                      SHU_Students (Canada)         923.96     171
# 6                         SHU_Students (USA)         897.68     178
# 7                          SHU_Students(UAE)         876.26     242
# 8                           SHU_Students(UK)         856.67     121
# 9                    SHU_Students(Australia)         850.68     119
# 10                       SHU_Students(Ghana)         837.78     648
#
#     IMPRESSIONS  REACH  CLICK THROUGH RATE  COST PER CLICK  COST PER RESULT
# 0         47139  23904            2.730000        1.835000         5.130000
# 1         67313  46494            5.930000        0.413333         1.033333
# 2         65215  29668            2.233333        0.723333         1.996667
# 3         37246  31831            4.305000        0.675000         1.055000
# 4         28974  21929            9.853333        0.346667         0.896667
# 5          4267   3307            5.513333        5.503333         7.930000
# 6          2900   2555            8.933333        4.813333         9.570000
# 7          8660   7333            2.646667        3.583333         9.350000
# 8          4091   3636            3.626667        7.453333        18.650000
# 9          3572   3187            4.353333        7.920000        23.106667
# 10        20483  15024            3.363333        1.283333         3.970000

# %% [markdown]
# ## Visualization
# ### Bar chart (The relationship between the campain name and the amount spent per campaign)

# %%
plt.figure(figsize=(12, 6))
plt.bar(campaign_summary['CAMPAIGN NAME'], campaign_summary['AMOUNT SPENT '], color='orange')
plt.xlabel('CAMPAIGN NAME')
plt.ylabel('AMOUNT SPENT')
plt.title('Amount spent by each campaign')
plt.xticks(rotation=90)
plt.plot(campaign_summary['CAMPAIGN NAME'], campaign_summary['AMOUNT SPENT '], marker='o', color='blue', linewidth=2)
plt.show()

# %% [markdown]
# ## Amount spent per campaign through reach

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.bar(campaign_summary['CAMPAIGN NAME'], campaign_summary['AMOUNT SPENT '], color='darkgreen', label='Amount Spent')
ax1.set_xlabel('CAMPAIGN NAME')
ax1.set_ylabel('AMOUNT SPENT', color='green')
ax1.tick_params(axis='y', labelcolor='green')
ax1.set_title('Amount spent per campaign through reach')
ax1.set_xticklabels(campaign_summary['CAMPAIGN NAME'], rotation=90)

ax2 = ax1.twinx()
ax2.plot(campaign_summary['CAMPAIGN NAME'], campaign_summary['REACH'], marker='o', color='red', label='REACH')
ax2.set_ylabel('REACH', color='red')
ax2.tick_params(axis='y', labelcolor='red')

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Amount spent per campaign through Impressions

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.bar(campaign_summary['CAMPAIGN NAME'], campaign_summary['AMOUNT SPENT '], color='darkgreen', label='Amount Spent')
ax1.set_xlabel('CAMPAIGN NAME')
ax1.set_ylabel('AMOUNT SPENT', color='green')
ax1.tick_params(axis='y', labelcolor='green')
ax1.set_title('Amount spent per campaign through Impressions')
ax1.set_xticklabels(campaign_summary['CAMPAIGN NAME'], rotation=90)

ax2 = ax1.twinx()
ax2.plot(campaign_summary['CAMPAIGN NAME'], campaign_summary['IMPRESSIONS'], marker='o', color='red', label='IMPRESSIONS')
ax2.set_ylabel('IMPRESSIONS', color='red')
ax2.tick_params(axis='y', labelcolor='red')

fig.tight_layout()
plt.show()
